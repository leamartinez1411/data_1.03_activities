# %%
import pandas as pd

# %% [markdown]
# ## 1.03 Activity 1

# %%
## 1.03 Activity 1

file3 = pd.read_excel("file3.xlsx")
file4 = pd.read_excel("file4.xlsx")

# %%
file3.head()
# Out:
#    CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    119966         TX      F   321  225  281     0   9372      3     68  264
# 1    152470         CA      F  5725  610  807    97  53158     13     22  763
# 2     48527         AL   Male   931  407  496     0  17743      0     65  502
# 3    171528         CA      F  1895  317  471    46  17431     10     62  389
# 4     50122  Tennessee      F   715  318  370     2  12416      0     75  340
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  243   8.058824      0  3212     T3      11.0
# 1  698  23.727273      0     0     S1      45.0
# 2  439   4.416667      2     0     R3       3.0
# 3  405   6.705882      0  5501     R2       5.0
# 4  352   9.250000      2     0     T1      10.0

# %%
names3 = list(file3.columns)

# %%
names4 = list(file4.columns)

# %%
names3 == names4
# Out:
# True

# %%
type(names3)
# Out:
# list

# %%
type(names4)
# Out:
# list

# %%
file3 = file3.rename(columns=str.lower)
file4 = file4.rename(columns=str.lower)

# %%
list(file3.columns)
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d']

# %%
list(file4.columns)
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d']

# %%
column_names=file3.columns
data = pd.DataFrame(columns = column_names)
data = pd.concat([data, file3, file4], axis = 0)
data.shape
# Out:
# (2006, 17)

# %%
data.head()
# Out:
#   controln      state gender   hv1  ic1  ic4 hvp1    ic5 pobc1 pobc2  ic2  \
# 0   119966         TX      F   321  225  281    0   9372     3    68  264
# 1   152470         CA      F  5725  610  807   97  53158    13    22  763
# 2    48527         AL   Male   931  407  496    0  17743     0    65  502
# 3   171528         CA      F  1895  317  471   46  17431    10    62  389
# 4    50122  Tennessee      F   715  318  370    2  12416     0    75  340
#
#    ic3    avggift tcode   dob domain  target_d
# 0  243   8.058824     0  3212     T3      11.0
# 1  698  23.727273     0     0     S1      45.0
# 2  439   4.416667     2     0     R3       3.0
# 3  405   6.705882     0  5501     R2       5.0
# 4  352   9.250000     2     0     T1      10.0

# %%
data.rename(columns={"hv1": "median_home_val"})
# Out:
#      controln      state gender median_home_val  ic1  ic4 hvp1    ic5 pobc1  \
# 0      119966         TX      F             321  225  281    0   9372     3
# 1      152470         CA      F            5725  610  807   97  53158    13
# 2       48527         AL   Male             931  407  496    0  17743     0
# 3      171528         CA      F            1895  317  471   46  17431    10
# 4       50122  Tennessee      F             715  318  370    2  12416     0
# ...       ...        ...    ...             ...  ...  ...  ...    ...   ...
# 1001    41537         FL      F             742  396  470    0  15356     7
# 1002     4881         FL      M             599  100  423    4  11670    10
# 1003    66358         ND      M             593  258  299    0  10186     1
# 1004     2231         WI   male             564  217  397    0  12315     0
# 1005    68534         MI      M             651  431  505    0  14845     7
#
# ...

# %% [markdown]
# ## 1.03 Activity 2

# %%
## 1.03 Activity 2

data2 = data.drop (columns="domain",inplace=False)
data3 = data2.drop (columns="dob",inplace=False)
data3.head()
# Out:
#   controln      state gender   hv1  ic1  ic4 hvp1    ic5 pobc1 pobc2  ic2  \
# 0   119966         TX      F   321  225  281    0   9372     3    68  264
# 1   152470         CA      F  5725  610  807   97  53158    13    22  763
# 2    48527         AL   Male   931  407  496    0  17743     0    65  502
# 3   171528         CA      F  1895  317  471   46  17431    10    62  389
# 4    50122  Tennessee      F   715  318  370    2  12416     0    75  340
#
#    ic3    avggift tcode  target_d
# 0  243   8.058824     0      11.0
# 1  698  23.727273     0      45.0
# 2  439   4.416667     2       3.0
# 3  405   6.705882     0       5.0
# 4  352   9.250000     2      10.0

# %%
list(data3.columns)
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
data4 = data3.rename(columns={"hv1": "median_home_val"})

# %%
list(data4.columns)
# Out:
# ['controln',
#  'state',
#  'gender',
#  'median_home_val',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
data4[['controln',
 'state',
 'gender', 
 'ic1',
 'ic4',
 'ic2',
 'ic3',
 'median_home_val',
 'hvp1',
 'ic5',
 'pobc1',
 'pobc2',
 'avggift',
 'tcode',
 'target_d']]
# Out:
#      controln      state gender  ic1  ic4  ic2  ic3 median_home_val hvp1  \
# 0      119966         TX      F  225  281  264  243             321    0
# 1      152470         CA      F  610  807  763  698            5725   97
# 2       48527         AL   Male  407  496  502  439             931    0
# 3      171528         CA      F  317  471  389  405            1895   46
# 4       50122  Tennessee      F  318  370  340  352             715    2
# ...       ...        ...    ...  ...  ...  ...  ...             ...  ...
# 1001    41537         FL      F  396  470  424  450             742    0
# 1002     4881         FL      M  100  423  406  200             599    4
# 1003    66358         ND      M  258  299  298  274             593    0
# 1004     2231         WI   male  217  397  386  295             564    0
# 1005    68534         MI      M  431  505  451  455             651    0
#
#         ic5 pobc1 pobc2    avggift tcode  target_d
# ...

# %%
data4[(data4["gender"]=="M")&(data4["state"]=="FL")]
# Out:
#      controln state gender median_home_val  ic1  ic4 hvp1    ic5 pobc1 pobc2  \
# 30      35581    FL      M             906  296  473    3  16729     4    37
# 31      46358    FL      M             715  362  408    0  12806     6    28
# 38      41545    FL      M             658  373  436    0  14942    11    23
# 55      11284    FL      M             934  324  478    9  17408     4    11
# 59      25678    FL      M             721  302  365    2  12474     3    51
# ...       ...   ...    ...             ...  ...  ...  ...    ...   ...   ...
# 962     36776    FL      M             653  319  379    0  12869    11    35
# 973      4881    FL      M             599  100  423    4  11670    10    27
# 992      6403    FL      M             677  311  313    0  12509     2    23
# 997      6443    FL      M             595  252  274    0  11132     8    11
# 1002     4881    FL      M             599  100  423    4  11670    10    27
#
#       ic2  ic3    avggift tcode  target_d
# ...

# %%
data4[(data4["gender"]=="F")&(data4["target_d"]<100)]
# Out:
#      controln      state gender median_home_val  ic1  ic4 hvp1    ic5 pobc1  \
# 0      119966         TX      F             321  225  281    0   9372     3
# 1      152470         CA      F            5725  610  807   97  53158    13
# 3      171528         CA      F            1895  317  471   46  17431    10
# 4       50122  Tennessee      F             715  318  370    2  12416     0
# 5       92293         IL      F            3359  878  973   87  35266    16
# ...       ...        ...    ...             ...  ...  ...  ...    ...   ...
# 991     77441         WI      F             725  316  376    0  11623     1
# 993    117326         TX      F            1715  554  837   34  31480     3
# 996     66762         MI      F             632  279  388    2  12653     1
# 998    151175         CA      F            2707  507  537   80  16165    24
# 1001    41537         FL      F             742  396  470    0  15356     7
#
#      pobc2  ic2  ic3    avggift tcode  target_d
# ...

# %% [markdown]
# # 1.03 Activity 3

# %%
# 1.03 Activity 3

# 1. Filter the results where the gender 
# is `F` and store the results in another DataFrame `filtered2`.

filtered2 = data4[(data4["gender"]=="F")]

# %%
# 2. Check the first 10 rows of the DataFrame 
# using the `head()` function.


filtered2.head(10)
# Out:
#    controln      state gender median_home_val  ic1  ic4 hvp1    ic5 pobc1  \
# 0    119966         TX      F             321  225  281    0   9372     3
# 1    152470         CA      F            5725  610  807   97  53158    13
# 3    171528         CA      F            1895  317  471   46  17431    10
# 4     50122  Tennessee      F             715  318  370    2  12416     0
# 5     92293         IL      F            3359  878  973   87  35266    16
# 6     47191         AL      F             950  264  378    3  20090     6
# 7     89288         IL      F            1243  414  507    9  15884    18
# 9     30051         GA      F             359  205  292    0   9279     0
# 12   110789         LA      F             324  129  277    1   9585     0
# 14   142662         CA      F            1188  166  243    5  10014    10
#
#    pobc2  ic2  ic3    avggift tcode  target_d
# 0     68  264  243   8.058824     0      11.0
# 1     22  763  698  23.727273     0      45.0
# ...

# %%
#3. Reset the index of `filtered2` with and without using the 
# parameter `drop=True` and check the difference in the results.

# Without  parameter `drop=True`

filtered2.reset_index()
# Out:
#      index controln      state gender median_home_val  ic1  ic4 hvp1    ic5  \
# 0        0   119966         TX      F             321  225  281    0   9372
# 1        1   152470         CA      F            5725  610  807   97  53158
# 2        3   171528         CA      F            1895  317  471   46  17431
# 3        4    50122  Tennessee      F             715  318  370    2  12416
# 4        5    92293         IL      F            3359  878  973   87  35266
# ..     ...      ...        ...    ...             ...  ...  ...  ...    ...
# 979    991    77441         WI      F             725  316  376    0  11623
# 980    993   117326         TX      F            1715  554  837   34  31480
# 981    996    66762         MI      F             632  279  388    2  12653
# 982    998   151175         CA      F            2707  507  537   80  16165
# 983   1001    41537         FL      F             742  396  470    0  15356
#
#     pobc1 pobc2  ic2  ic3    avggift tcode  target_d
# ...

# %%
# With parameter `drop=True`

filtered2.reset_index(drop=True)
# Out:
#     controln      state gender median_home_val  ic1  ic4 hvp1    ic5 pobc1  \
# 0     119966         TX      F             321  225  281    0   9372     3
# 1     152470         CA      F            5725  610  807   97  53158    13
# 2     171528         CA      F            1895  317  471   46  17431    10
# 3      50122  Tennessee      F             715  318  370    2  12416     0
# 4      92293         IL      F            3359  878  973   87  35266    16
# ..       ...        ...    ...             ...  ...  ...  ...    ...   ...
# 979    77441         WI      F             725  316  376    0  11623     1
# 980   117326         TX      F            1715  554  837   34  31480     3
# 981    66762         MI      F             632  279  388    2  12653     1
# 982   151175         CA      F            2707  507  537   80  16165    24
# 983    41537         FL      F             742  396  470    0  15356     7
#
#     pobc2  ic2  ic3    avggift tcode  target_d
# ...

# %%
# 4. Show the rows from index number 100 to 200.

filtered2.iloc[100:200]
# Out:
#     controln state gender median_home_val  ic1  ic4 hvp1    ic5 pobc1 pobc2  \
# 198    35908    FL      F             693  373  463    7  16854     1    24
# 201    81073    WI      F             571  243  349    0  13144     3    74
# 202    38471    FL      F            1033  471  598   25  22327     6    36
# 208    95536    IL      F             886  482  433    3  13887     0    68
# 209   103330    MO      F             915  377  492    7  16206     3    62
# ..       ...   ...    ...             ...  ...  ...  ...    ...   ...   ...
# 404    90566    IL      F            1181  417  449    0  13716     2    69
# 405   186013    AL      F             554  296  391    4  12774     1    63
# 408    95132    IL      F             512  269  357    1  12842     1    73
# 409   130926    CO      F            1175  517  599    8  18850     2    38
# 413   114912    OK      F             622  306  345    0  10625     0    64
#
#      ic2  ic3    avggift tcode  target_d
# ...

# %%
# 5. Use `iloc` to get the first 100 rows and columns with indexes 2,3,4,5.

filtered2.iloc[0:100,2:6]
# Out:
#     gender median_home_val  ic1  ic4
# 0        F             321  225  281
# 1        F            5725  610  807
# 3        F            1895  317  471
# 4        F             715  318  370
# 5        F            3359  878  973
# ..     ...             ...  ...  ...
# 187      F             885  207  220
# 188      F             824  263  352
# 190      F             570  226  301
# 193      F             590  252  329
# 194      F             238  176  287
#
# [100 rows x 4 columns]

# %% [markdown]
# # 1.03 Activity 4

# %%
# 1.03 Activity 4
# 1. Check the data types of all the columns in the DataFrame.

filtered2.dtypes
# Out:
# controln            object
# state               object
# gender              object
# median_home_val     object
# ic1                 object
# ic4                 object
# hvp1                object
# ic5                 object
# pobc1               object
# pobc2               object
# ic2                 object
# ic3                 object
# avggift            float64
# tcode               object
# target_d           float64
# dtype: object

# %%
# 2. Use `select_dtypes()` to select all the numerical columns in the DataFrame (both integers and floats).

filtered2.select_dtypes("float","int")
# Out:
#         avggift  target_d
# 0      8.058824      11.0
# 1     23.727273      45.0
# 3      6.705882       5.0
# 4      9.250000      10.0
# 5      5.800000       5.0
# ...         ...       ...
# 991    7.666667       7.0
# 993    6.916667      10.0
# 996    8.533333       5.0
# 998   12.117647      22.0
# 1001  14.285714      50.0
#
# [984 rows x 2 columns]

# %%
list(filtered2.columns)
# Out:
# ['controln',
#  'state',
#  'gender',
#  'median_home_val',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
# 3. Convert the columns that have numerical values (which are now object types) to the numeric type.

filtered2['controln'].astype("float64")

#filtered2['controln'].value_counts()
# Out:
# 0       119966.0
# 1       152470.0
# 3       171528.0
# 4        50122.0
# 5        92293.0
#           ...
# 991      77441.0
# 993     117326.0
# 996      66762.0
# 998     151175.0
# 1001     41537.0
# Name: controln, Length: 984, dtype: float64

# %%
# 4. Remove duplicates from the DataFrame if any.

filtered2.drop_duplicates()
# Out:
#     controln      state gender median_home_val  ic1  ic4 hvp1    ic5 pobc1  \
# 0     119966         TX      F             321  225  281    0   9372     3
# 1     152470         CA      F            5725  610  807   97  53158    13
# 3     171528         CA      F            1895  317  471   46  17431    10
# 4      50122  Tennessee      F             715  318  370    2  12416     0
# 5      92293         IL      F            3359  878  973   87  35266    16
# ..       ...        ...    ...             ...  ...  ...  ...    ...   ...
# 989    26009         GA      F             899  396  501    1  15973     6
# 991    77441         WI      F             725  316  376    0  11623     1
# 993   117326         TX      F            1715  554  837   34  31480     3
# 996    66762         MI      F             632  279  388    2  12653     1
# 998   151175         CA      F            2707  507  537   80  16165    24
#
#     pobc2  ic2  ic3    avggift tcode  target_d
# ...
